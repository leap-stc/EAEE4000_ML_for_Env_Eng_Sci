# %% [markdown]
# This notebook shows how to apply Neural Networks to predict the global temperature, based on the time series of CO2 & CH4.
#
# By Weiwei Zhan
#
# modify by Rong-Yu Gu, 09/12/2023

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
from glob import glob

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras import Sequential
from utils import * 

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

plt.rcParams['savefig.dpi'] = 400
plt.rcParams['font.size'] = 13
plt.rcParams["legend.frameon"] = False
# Out:
# 2023-09-12 23:56:02.014132: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-12 23:56:02.066440: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
cwd = os.getcwd()
train_path = "gs://leap-persistent/jbusecke/data/climatebench/train_val/"
test_path = "gs://leap-persistent/jbusecke/data/climatebench/test/"

# %% [markdown]
# ## Some visualization of the ClimateBench data

# %% [markdown]
# Before training ML models, let's plot the ClimateBench dataset for quick checking.
#
# <a href="https://github.com/duncanwp/ClimateBench.git">ClimateBench</a> is a spatial-temporal dataset that contains simulations generated by the NorESM2 model. It provides both historical simulations & future projections under different scenarios (e.g., ssp245).
#
# Four future scenarios are plotted here: `ssp126, ssp245, ssp370, ssp585`.
#
# reference: <a href="https://doi.org/10.1029/2021MS002954">Watson‐Parris, D., Rao, Y., Olivié, D., Seland, Ø., Nowack, P., Camps‐Valls, G., ... & Roesch, C. (2022). ClimateBench v1. 0: A Benchmark for Data‐Driven Climate Projections. Journal of Advances in Modeling Earth Systems, 14(10), e2021MS002954.</a>

# %%
scenarios = ['historical','ssp126','ssp370','ssp585']
inputs = [os.path.join(train_path , f"inputs_{scenario}") for scenario in scenarios]
inputs.append(os.path.join(test_path, "inputs_ssp245"))
inputs.sort(key=lambda x:x.split('_')[-1])

outputs = [os.path.join(train_path , f"outputs_{scenario}") for scenario in scenarios]
outputs.append(os.path.join(test_path, "outputs_ssp245"))
outputs.sort(key=lambda x:x.split('_')[-1])

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4))
colors  = ['tab:blue','tab:green','tab:purple','tab:orange','tab:red']


for i,input in enumerate(inputs):

    label=input.split('_')[-1]#[:-3]
    X = open_dataset(input)
    x = X.time.data
    
    X['CO2'].plot(label=label,color=colors[i],linewidth=2,ax=axes[0])
    # axes[0].plot(x, X['CO2'].data, label=label,color=colors[i],linewidth=2)
    axes[0].set_ylabel("Cumulative anthropogenic CO2 \nemissions since 1850 (GtCO2)")
    
    X['CH4'].plot(label=label,color=colors[i],linewidth=2,ax=axes[1])
    # axes[1].plot(x, X['CH4'].data, label=label,color=colors[i],linewidth=2)
    axes[1].set_ylabel("Anthropogenic CH4 \nemissions (GtCH4 / year)")
    
axes[0].set_title('CO2')
axes[1].set_title('CH4')
axes[0].legend()
plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 1, figsize=(9,4))

for i,output in enumerate(outputs):

    label=output.split('_')[-1]#[:-3]
    X = open_dataset(output).mean(dim="member")[['tas']].drop(['quantile'])
    x = X.time.data
    
    weights  = np.cos(np.deg2rad(X.lat))
    tas_mean = X['tas'].weighted(weights).mean(['lat', 'lon']).data
    tas_std  = X['tas'].weighted(weights).std(['lat', 'lon']).data
    
    ax.plot(x, tas_mean, label=label,color=colors[i],linewidth=2)
    ax.fill_between(x,tas_mean+tas_std,tas_mean-tas_std,facecolor=colors[i],alpha=0.2)
    
ax.set_ylabel("Global average temperature\n since 1850 (°C)")
ax.legend()
plt.tight_layout()

# %%
y_his    = open_dataset(os.path.join(train_path , "outputs_historical")).mean(dim="member")[['tas']].drop(['quantile'])
y_ssp370 = open_dataset(os.path.join(train_path,'outputs_ssp370')).mean(dim="member")[['tas']].drop(['quantile'])


fig,axes = plt.subplots(figsize=(18,4.5),ncols=3)
yr0, yr1, yr2 = 1900, 1950, 2000
vmin, vmax = -5, 5

y_his.sel(time=yr0).tas.plot(ax=axes.flat[0],vmin=vmin,vmax=vmax,cmap='RdBu_r')
y_his.sel(time=yr1).tas.plot(ax=axes.flat[1],vmin=vmin,vmax=vmax,cmap='RdBu_r')
y_his.sel(time=yr2).tas.plot(ax=axes.flat[2],vmin=vmin,vmax=vmax,cmap='RdBu_r')

fig.suptitle('historical simulations for temperature',fontweight='bold')
plt.tight_layout()

# %%
y_ssp370 = open_dataset(os.path.join(train_path,'outputs_ssp370')).mean(dim="member")[['tas']].drop(['quantile'])


fig,axes = plt.subplots(figsize=(18,4.5),ncols=3)
yr0, yr1, yr2 = 2020, 2050, 2100
vmin, vmax = -5, 5

y_ssp370.sel(time=yr0).tas.plot(ax=axes.flat[0],vmin=vmin,vmax=vmax,cmap='RdBu_r')
y_ssp370.sel(time=yr1).tas.plot(ax=axes.flat[1],vmin=vmin,vmax=vmax,cmap='RdBu_r')
y_ssp370.sel(time=yr2).tas.plot(ax=axes.flat[2],vmin=vmin,vmax=vmax,cmap='RdBu_r')

fig.suptitle('future simulations (ssp370) for temperature',fontweight='bold')
plt.tight_layout()

# %% [markdown]
# ## Use Neural Networks (NN) for temperature prediction
#
#
# Now, we are trying to use NN to predict the surface air temperature (tas), based on the time series of CO2 & CH4 emissions

# %% [markdown]
# ### 1. data preprocssing: prepare data for training & test sets

# %% [markdown]
# #### import data as training & test sets
#
# Here we train NN using simulations from 3 historical and 3 future scenarios. <br/> Then we test the trained NN using the ssp245 scenario.

# %%
# Training set
train_files    = ["historical", "ssp585", "ssp126", "ssp370","hist-aer","hist-GHG"]
X_train_xr, _  = prepare_predictor(train_files,train_path)
y_train_xr, _  = prepare_predictand(train_files,train_path)

# Test set
X_test_xr, _ = prepare_predictor('ssp245', data_path=test_path,time_reindex=False)
y_test_xr, _ = prepare_predictand('ssp245',data_path=test_path,time_reindex=False)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### select relevant variables
#
# predictors: CO2 & CH4 <br/>
# predictand: tas

# %%
X_train_df = pd.DataFrame({"CO2": X_train_xr["CO2"].data,
                           "CH4": X_train_xr["CH4"].data
                          }, index=X_train_xr["CO2"].coords['time'].data)

X_test_df  = pd.DataFrame({"CO2": X_test_xr["CO2"].data,
                           "CH4": X_test_xr["CH4"].data
                          }, index=X_test_xr["CO2"].coords['time'].data)


y_train_df = y_train_xr["tas"].stack(dim=["latitude", "longitude"])
y_train_df = pd.DataFrame(y_train_df.to_pandas())

# %% [markdown]
# This is how our predictors & predictand data look like:

# %%
X_train_df.head()
# Out:
#         CO2       CH4
# 0  0.188297  0.031306
# 1  0.377244  0.031742
# 2  0.573814  0.032178
# 3  0.778848  0.032614
# 4  1.020320  0.033049

# %% [markdown]
# Note that here we stack the original 2-D tas data into a single dimension (for the purpose of NN implementation)

# %%
y_train_df.head()
# Out:
# latitude      -90.0                                                    \
# longitude     0.0       2.5       5.0       7.5       10.0      12.5
# time
# 0          0.320023  0.319946  0.319865  0.319885  0.319860  0.319865
# 1         -0.667297 -0.667023 -0.667114 -0.667109 -0.667109 -0.667135
# 2         -0.058345 -0.058167 -0.058248 -0.058243 -0.058248 -0.058248
# 3          0.125870  0.125941  0.125946  0.125941  0.125946  0.125890
# 4          0.418304  0.418533  0.418503  0.418523  0.418477  0.418513
#
# latitude                                           ...      90.0            \
# longitude     15.0      17.5      20.0      22.5   ...     335.0     337.5
# time                                               ...
# 0          0.319870  0.319911  0.319763  0.319707  ...  0.913116  0.913289
# 1         -0.667114 -0.667104 -0.667104 -0.666992  ...  0.042501  0.042679
# 2         -0.058233 -0.058207 -0.058345 -0.058177  ...  1.167440  1.167389
# 3          0.125951  0.125941  0.125895  0.125982  ... -0.339457 -0.339589
# 4          0.418503  0.418549  0.418482  0.418564  ...  0.577006  0.576996
#
# latitude                                                               \
# longitude     340.0     342.5     345.0     347.5     350.0     352.5
# time
# 0          0.913116  0.912933  0.912893  0.912659  0.912384  0.912181
# 1          0.049225  0.055695  0.055506  0.055227  0.054789  0.054230
# 2          1.169657  1.172119  1.172201  1.172190  1.172292  1.172424
# 3         -0.332387 -0.324961 -0.324956 -0.325038 -0.325063 -0.325033
# 4          0.585297  0.593811  0.593740  0.593719  0.593648  0.593801
#
# latitude
# longitude     355.0     357.5
# time
# 0          0.911825  0.911611
# 1          0.053604  0.052897
# 2          1.172709  1.173228
# 3         -0.325022 -0.324880
# 4          0.593760  0.593943
#
# [5 rows x 13824 columns]

# %% [markdown]
# #### Data normalization
#
# Let's normalize the input predictors by there mean & std

# %%
# Standardization
mean, std = X_train_df.mean(), X_train_df.std()

X_train_df   = (X_train_df - mean)/std
X_test_df    = (X_test_df - mean)/std

X_train = X_train_df.to_numpy()
y_train = y_train_df.to_numpy()
X_test = X_test_df.to_numpy()

print(X_train.shape,y_train.shape)
# Out:
# (753, 2) (753, 13824)

# %% [markdown]
# ### 2. Define the NN structure

# %% [markdown]
# Now the data preprocessing has been finished! Let's define our NN structure, which is shown in the below schematic.
#
# Here the NN we use has 3 hidden layers, and each hidden layer has 64 neurons.
#
# The NN input layer has 2 neurons, corresponding to CO2 & CH4 inputs respectively.
#
# The NN outputs are the global tas, each neuron of the output layer corresponds to each pixel. There are 13824 pixels in total (number of latitude: 96, number of longitude: 144)

# %% [markdown]
# ![title](https://drive.google.com/uc?export=view&id=1wCIEX6GAN5h0_XOd23eUtdnkjpOJPpde)

# %% [markdown]
# Here are the hyperparameters for the NN training, such as the number of neurons per layer, learning rate, etc. Note that these hyperparameters here are for demonstration purposes only - they are not optimized.

# %%
# set hyperparameters
n_neuron       = 64
activation     = 'relu'
num_epochs     = 50
learning_rate  = 0.001
minibatch_size = 64
model_num      = 1
N_layers       = 2 # number of hidden layers

# %%
# let us build a neural network from scratch

# using mse as loss function (mse: mean square error)
model_mse = Sequential()
model_mse.add(Dense(n_neuron,  activation=activation, name="hidden_layer_1" ,input_shape=(X_train.shape[1],)))
for n in range(N_layers-1):
    model_mse.add(Dense(n_neuron,  activation=activation, name="hidden_layer_"+str(n+2))) 
model_mse.add(Dense(y_train.shape[1],  activation='linear', name="output_layer")) # the output layer
model_mse.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
model_mse.summary()
print('************************************************')


# using mae as loss function (mae: mean absolute error)
model_mae = Sequential()
model_mae.add(Dense(n_neuron,  activation=activation, name="hidden_layer_1" ,input_shape=(X_train.shape[1],)))
for n in range(N_layers-1):
    model_mae.add(Dense(n_neuron,  activation=activation, name="hidden_layer_"+str(n+2))) 
model_mae.add(Dense(y_train.shape[1],  activation='linear', name="output_layer")) # the output layer
model_mae.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
model_mae.summary()
print('************************************************')


# using mape as loss function (mape: mean absolute percentage error)
model_mape = Sequential()
model_mape.add(Dense(n_neuron,  activation=activation, name="hidden_layer_1" ,input_shape=(X_train.shape[1],)))
for n in range(N_layers-1):
    model_mape.add(Dense(n_neuron,  activation=activation, name="hidden_layer_"+str(n+2))) 
model_mape.add(Dense(y_train.shape[1],  activation='linear', name="output_layer")) # the output layer
model_mape.compile(loss='mean_absolute_percentage_error',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
model_mape.summary()
print('************************************************')


# using quantile loss function 
def quantile_loss(y_true, y_pred):
    q = 0.5
    e = y_true-y_pred
    loss = tf.keras.backend.mean(tf.keras.backend.maximum(q*e, (q-1)*e))
    return loss
#quantile = 0.5
model_qloss = Sequential()
model_qloss.add(Dense(n_neuron,  activation=activation, name="hidden_layer_1" ,input_shape=(X_train.shape[1],)))
for n in range(N_layers-1):
    model_qloss.add(Dense(n_neuron,  activation=activation, name="hidden_layer_"+str(n+2))) 
model_qloss.add(Dense(y_train.shape[1],  activation='linear', name="output_layer")) # the output layer
model_qloss.compile(loss=quantile_loss,
                    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
model_qloss.summary()
print('************************************************')
# lambda y, y_p: quantile_loss(quantile, y, y_p)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 64)                192
#
#  hidden_layer_2 (Dense)      (None, 64)                4160
#
#  output_layer (Dense)        (None, 13824)             898560
#
# =================================================================
# Total params: 902,912
# Trainable params: 902,912
# Non-trainable params: 0
# _________________________________________________________________
# ************************************************
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 64)                192
#
#  hidden_layer_2 (Dense)      (None, 64)                4160
#
#  output_layer (Dense)        (None, 13824)             898560
#
# =================================================================
# Total params: 902,912
# Trainable params: 902,912
# Non-trainable params: 0
# _________________________________________________________________
# ************************************************
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 64)                192
#
#  hidden_layer_2 (Dense)      (None, 64)                4160
#
#  output_layer (Dense)        (None, 13824)             898560
#
# =================================================================
# Total params: 902,912
# Trainable params: 902,912
# Non-trainable params: 0
# _________________________________________________________________
# ************************************************
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 64)                192
#
#  hidden_layer_2 (Dense)      (None, 64)                4160
#
#  output_layer (Dense)        (None, 13824)             898560
#
# =================================================================
# Total params: 902,912
# Trainable params: 902,912
# Non-trainable params: 0
# _________________________________________________________________
# ************************************************

# %% [markdown]
# ### 3. Train & save the NN model

# %% [markdown]
# Here we use `EarlyStopping` to avoid over-fitting

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

### train NN models
# ----------mse----------
history_mse = model_mse.fit(X_train, y_train, 
                            batch_size      = minibatch_size,
                            epochs          = num_epochs,
                            validation_split= 0.2, 
                            verbose         = 1,
                            callbacks       = [early_stop])
print('****************** end of mse ***********************')
# ----------mae----------
history_mae = model_mae.fit(X_train, y_train, 
                            batch_size      = minibatch_size,
                            epochs          = num_epochs,
                            validation_split= 0.2, 
                            verbose         = 1,
                            callbacks       = [early_stop])
print('****************** end of mae ***********************')
# ----------mape----------
history_mape = model_mape.fit(X_train, y_train, 
                              batch_size      = minibatch_size,
                              epochs          = num_epochs,
                              validation_split= 0.2, 
                              verbose         = 1,
                              callbacks       = [early_stop])
print('****************** end of mape ***********************')
# ----------quantile loss----------
history_qloss = model_qloss.fit(X_train, y_train, 
                                batch_size      = minibatch_size,
                                epochs          = num_epochs,
                                validation_split= 0.2, 
                                verbose         = 1,
                                callbacks       = [early_stop])
print('****************** end of qloss ***********************')
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 62ms/step - loss: 3.6590 - val_loss: 0.5599
# Epoch 2/50
# 10/10 [==============================] - 0s 48ms/step - loss: 3.4105 - val_loss: 0.5278
# Epoch 3/50
# 10/10 [==============================] - 0s 47ms/step - loss: 2.9206 - val_loss: 0.4770
# Epoch 4/50
# 10/10 [==============================] - 0s 52ms/step - loss: 2.2520 - val_loss: 0.4039
# Epoch 5/50
# 10/10 [==============================] - 0s 47ms/step - loss: 1.4860 - val_loss: 0.3296
# Epoch 6/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.9111 - val_loss: 0.2895
# Epoch 7/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.6162 - val_loss: 0.2901
# Epoch 8/50
# 10/10 [==============================] - 1s 55ms/step - loss: 0.4709 - val_loss: 0.3060
# Epoch 9/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.4288 - val_loss: 0.3005
# Epoch 10/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.4126 - val_loss: 0.2948
# Epoch 11/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3998 - val_loss: 0.3040
# Epoch 12/50
# 10/10 [==============================] - 0s 52ms/step - loss: 0.3923 - val_loss: 0.3025
# Epoch 13/50
# 10/10 [==============================] - 0s 55ms/step - loss: 0.3869 - val_loss: 0.2957
# Epoch 14/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3829 - val_loss: 0.2883
# Epoch 15/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3804 - val_loss: 0.2975
# Epoch 16/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3772 - val_loss: 0.2810
# Epoch 17/50
# 10/10 [==============================] - 0s 52ms/step - loss: 0.3753 - val_loss: 0.2807
# Epoch 18/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.3733 - val_loss: 0.2830
# Epoch 19/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3721 - val_loss: 0.2783
# Epoch 20/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3700 - val_loss: 0.2766
# Epoch 21/50
# 10/10 [==============================] - 1s 67ms/step - loss: 0.3688 - val_loss: 0.2833
# Epoch 22/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3669 - val_loss: 0.2763
# Epoch 23/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3659 - val_loss: 0.2796
# Epoch 24/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3645 - val_loss: 0.2764
# Epoch 25/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.3633 - val_loss: 0.2749
# Epoch 26/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.3625 - val_loss: 0.2824
# Epoch 27/50
# 10/10 [==============================] - 0s 53ms/step - loss: 0.3617 - val_loss: 0.2783
# Epoch 28/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3607 - val_loss: 0.2769
# Epoch 29/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3599 - val_loss: 0.2804
# Epoch 30/50
# 10/10 [==============================] - 0s 51ms/step - loss: 0.3593 - val_loss: 0.2807
# Epoch 31/50
# 10/10 [==============================] - 0s 54ms/step - loss: 0.3581 - val_loss: 0.2769
# Epoch 32/50
# 10/10 [==============================] - 0s 55ms/step - loss: 0.3578 - val_loss: 0.2830
# Epoch 33/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3576 - val_loss: 0.2805
# Epoch 34/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3568 - val_loss: 0.2787
# Epoch 35/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3556 - val_loss: 0.2816
# Epoch 36/50
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3550 - val_loss: 0.2807
# Epoch 37/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3544 - val_loss: 0.2870
# Epoch 38/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3538 - val_loss: 0.2911
# Epoch 39/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3526 - val_loss: 0.2873
# Epoch 40/50
# 10/10 [==============================] - 0s 49ms/step - loss: 0.3520 - val_loss: 0.2937
# Epoch 41/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3513 - val_loss: 0.2880
# Epoch 42/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3514 - val_loss: 0.2962
# Epoch 43/50
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3514 - val_loss: 0.2942
# Epoch 44/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3496 - val_loss: 0.2980
# Epoch 45/50
# 10/10 [==============================] - 4s 457ms/step - loss: 0.3490 - val_loss: 0.2957
# ****************** end of mse ***********************
# Epoch 1/50
# 10/10 [==============================] - 11s 62ms/step - loss: 3.6581 - val_loss: 0.5565
# Epoch 2/50
# 10/10 [==============================] - 0s 47ms/step - loss: 3.3570 - val_loss: 0.5164
# Epoch 3/50
# 10/10 [==============================] - 0s 45ms/step - loss: 2.8705 - val_loss: 0.4544
# Epoch 4/50
# 10/10 [==============================] - 0s 47ms/step - loss: 2.1331 - val_loss: 0.3826
# Epoch 5/50
# 10/10 [==============================] - 1s 56ms/step - loss: 1.4182 - val_loss: 0.3220
# Epoch 6/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.9233 - val_loss: 0.2869
# Epoch 7/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.6383 - val_loss: 0.2792
# Epoch 8/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.5031 - val_loss: 0.3096
# Epoch 9/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.4572 - val_loss: 0.3074
# Epoch 10/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.4305 - val_loss: 0.3077
# Epoch 11/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.4136 - val_loss: 0.3316
# Epoch 12/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.4032 - val_loss: 0.3194
# Epoch 13/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3951 - val_loss: 0.3213
# Epoch 14/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3904 - val_loss: 0.3021
# Epoch 15/50
# 10/10 [==============================] - 0s 51ms/step - loss: 0.3859 - val_loss: 0.3020
# Epoch 16/50
# 10/10 [==============================] - 1s 55ms/step - loss: 0.3825 - val_loss: 0.2914
# Epoch 17/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3798 - val_loss: 0.2862
# Epoch 18/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3775 - val_loss: 0.2789
# Epoch 19/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3759 - val_loss: 0.2771
# Epoch 20/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3741 - val_loss: 0.2674
# Epoch 21/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3724 - val_loss: 0.2719
# Epoch 22/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3718 - val_loss: 0.2725
# Epoch 23/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3693 - val_loss: 0.2682
# Epoch 24/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3689 - val_loss: 0.2745
# Epoch 25/50
# 10/10 [==============================] - 0s 44ms/step - loss: 0.3668 - val_loss: 0.2593
# Epoch 26/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3662 - val_loss: 0.2728
# Epoch 27/50
# 10/10 [==============================] - 0s 54ms/step - loss: 0.3647 - val_loss: 0.2649
# Epoch 28/50
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3641 - val_loss: 0.2741
# Epoch 29/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3625 - val_loss: 0.2683
# Epoch 30/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3621 - val_loss: 0.2720
# Epoch 31/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3616 - val_loss: 0.2770
# Epoch 32/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3606 - val_loss: 0.2760
# Epoch 33/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3599 - val_loss: 0.2780
# Epoch 34/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3591 - val_loss: 0.2828
# Epoch 35/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3581 - val_loss: 0.2773
# Epoch 36/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3578 - val_loss: 0.2706
# Epoch 37/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3578 - val_loss: 0.2842
# Epoch 38/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3568 - val_loss: 0.2757
# Epoch 39/50
# 10/10 [==============================] - 1s 55ms/step - loss: 0.3557 - val_loss: 0.2784
# Epoch 40/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3552 - val_loss: 0.2836
# Epoch 41/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3552 - val_loss: 0.2803
# Epoch 42/50
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3551 - val_loss: 0.2841
# Epoch 43/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3539 - val_loss: 0.2874
# Epoch 44/50
# 10/10 [==============================] - 0s 54ms/step - loss: 0.3534 - val_loss: 0.2788
# Epoch 45/50
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3540 - val_loss: 0.2795
# ****************** end of mae ***********************
# Epoch 1/50
# 10/10 [==============================] - 1s 70ms/step - loss: 132.4223 - val_loss: 151.6275
# Epoch 2/50
# 10/10 [==============================] - 1s 56ms/step - loss: 159.0595 - val_loss: 142.3142
# Epoch 3/50
# 10/10 [==============================] - 1s 66ms/step - loss: 126.9655 - val_loss: 127.7005
# Epoch 4/50
# 10/10 [==============================] - 1s 57ms/step - loss: 117.4976 - val_loss: 121.1696
# Epoch 5/50
# 10/10 [==============================] - 1s 56ms/step - loss: 114.1025 - val_loss: 131.7663
# Epoch 6/50
# 10/10 [==============================] - 1s 57ms/step - loss: 118.4361 - val_loss: 128.7858
# Epoch 7/50
# 10/10 [==============================] - 1s 49ms/step - loss: 109.8241 - val_loss: 125.7083
# Epoch 8/50
# 10/10 [==============================] - 1s 57ms/step - loss: 112.4347 - val_loss: 131.9989
# Epoch 9/50
# 10/10 [==============================] - 1s 56ms/step - loss: 108.1742 - val_loss: 134.8354
# Epoch 10/50
# 10/10 [==============================] - 1s 58ms/step - loss: 109.5953 - val_loss: 130.3082
# Epoch 11/50
# 10/10 [==============================] - 1s 56ms/step - loss: 109.1602 - val_loss: 125.2800
# Epoch 12/50
# 10/10 [==============================] - 1s 65ms/step - loss: 108.8948 - val_loss: 128.4342
# Epoch 13/50
# 10/10 [==============================] - 1s 58ms/step - loss: 104.9890 - val_loss: 130.4592
# Epoch 14/50
# 10/10 [==============================] - 1s 56ms/step - loss: 106.0488 - val_loss: 128.5043
# Epoch 15/50
# 10/10 [==============================] - 1s 57ms/step - loss: 105.5969 - val_loss: 130.3159
# Epoch 16/50
# 10/10 [==============================] - 1s 56ms/step - loss: 107.2504 - val_loss: 130.0419
# Epoch 17/50
# 10/10 [==============================] - 1s 57ms/step - loss: 103.1541 - val_loss: 127.4017
# Epoch 18/50
# 10/10 [==============================] - 1s 49ms/step - loss: 101.1730 - val_loss: 126.7099
# Epoch 19/50
# 10/10 [==============================] - 1s 56ms/step - loss: 100.7008 - val_loss: 127.1814
# Epoch 20/50
# 10/10 [==============================] - 1s 57ms/step - loss: 101.4660 - val_loss: 127.7210
# Epoch 21/50
# 10/10 [==============================] - 1s 56ms/step - loss: 97.9068 - val_loss: 129.4641
# Epoch 22/50
# 10/10 [==============================] - 1s 66ms/step - loss: 99.0950 - val_loss: 128.1868
# Epoch 23/50
# 10/10 [==============================] - 1s 58ms/step - loss: 96.5791 - val_loss: 124.7507
# Epoch 24/50
# 10/10 [==============================] - 1s 56ms/step - loss: 99.1701 - val_loss: 126.2146
# ****************** end of mape ***********************
# Epoch 1/50
# 10/10 [==============================] - 1s 69ms/step - loss: 0.5781 - val_loss: 0.2590
# Epoch 2/50
# 10/10 [==============================] - 1s 64ms/step - loss: 0.5543 - val_loss: 0.2517
# Epoch 3/50
# 10/10 [==============================] - 1s 66ms/step - loss: 0.5055 - val_loss: 0.2391
# Epoch 4/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.4280 - val_loss: 0.2193
# Epoch 5/50
# 10/10 [==============================] - 1s 69ms/step - loss: 0.3458 - val_loss: 0.1999
# Epoch 6/50
# 10/10 [==============================] - 1s 68ms/step - loss: 0.2987 - val_loss: 0.1972
# Epoch 7/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.2596 - val_loss: 0.1996
# Epoch 8/50
# 10/10 [==============================] - 1s 68ms/step - loss: 0.2364 - val_loss: 0.1935
# Epoch 9/50
# 10/10 [==============================] - 1s 69ms/step - loss: 0.2268 - val_loss: 0.1939
# Epoch 10/50
# 10/10 [==============================] - 1s 68ms/step - loss: 0.2224 - val_loss: 0.1928
# Epoch 11/50
# 10/10 [==============================] - 1s 68ms/step - loss: 0.2194 - val_loss: 0.1903
# Epoch 12/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.2172 - val_loss: 0.1883
# Epoch 13/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.2157 - val_loss: 0.1880
# Epoch 14/50
# 10/10 [==============================] - 1s 67ms/step - loss: 0.2146 - val_loss: 0.1865
# Epoch 15/50
# 10/10 [==============================] - 1s 67ms/step - loss: 0.2136 - val_loss: 0.1872
# Epoch 16/50
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2130 - val_loss: 0.1880
# Epoch 17/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2125 - val_loss: 0.1893
# Epoch 18/50
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2119 - val_loss: 0.1910
# Epoch 19/50
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2117 - val_loss: 0.1898
# Epoch 20/50
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2114 - val_loss: 0.1905
# Epoch 21/50
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2110 - val_loss: 0.1906
# Epoch 22/50
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2109 - val_loss: 0.1919
# Epoch 23/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2107 - val_loss: 0.1916
# Epoch 24/50
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2103 - val_loss: 0.1922
# Epoch 25/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2105 - val_loss: 0.1927
# Epoch 26/50
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2099 - val_loss: 0.1927
# Epoch 27/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2097 - val_loss: 0.1919
# Epoch 28/50
# 10/10 [==============================] - 1s 68ms/step - loss: 0.2096 - val_loss: 0.1920
# Epoch 29/50
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2093 - val_loss: 0.1945
# Epoch 30/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2092 - val_loss: 0.1929
# Epoch 31/50
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2090 - val_loss: 0.1928
# Epoch 32/50
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2087 - val_loss: 0.1937
# Epoch 33/50
# 10/10 [==============================] - 1s 66ms/step - loss: 0.2086 - val_loss: 0.1946
# Epoch 34/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2086 - val_loss: 0.1924
# ****************** end of qloss ***********************

# %%
plt.subplot(2, 2, 1)
plt.plot(history_mse.history['loss'])
plt.plot(history_mse.history['val_loss'])
plt.title('loss: Mean Squared Error', fontsize=12)
plt.ylabel('mse')
plt.xlabel('Epoch')
plt.legend(['Train loss', 'Val loss'], fontsize=10, loc='upper right')


plt.subplot(2, 2, 2)
plt.plot(history_mae.history['loss'])
plt.plot(history_mae.history['val_loss'])
plt.title('loss: Mean Absolute Error', fontsize=12)
plt.ylabel('mae')
plt.xlabel('Epoch')
plt.legend(['Train loss', 'Val loss'], fontsize=10, loc='upper right')


plt.subplot(2, 2, 3)
plt.plot(history_mape.history['loss'])
plt.plot(history_mape.history['val_loss'])
plt.title('loss: Mean Absolute Percentage Error', fontsize=10)
plt.ylabel('mape')
plt.xlabel('Epoch')
plt.legend(['Train loss', 'Val loss'], fontsize=10, loc='upper right')


plt.subplot(2, 2, 4)
plt.plot(history_qloss.history['loss'])
plt.plot(history_qloss.history['val_loss'])
plt.title('loss: Quantile Loss Function', fontsize=10)
plt.ylabel('quantile loss (50th)')
plt.xlabel('Epoch')
plt.legend(['Train loss', 'Val loss'], fontsize=10, loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# we can save the trained model as the `.h5` file.

# %%
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)

# %%
# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model_mse.save(os.path.join(model_path,'NN_mse_model.h5'))
model_mae.save(os.path.join(model_path,'NN_mae_model.h5'))
model_mape.save(os.path.join(model_path,'NN_mape_model.h5'))
model_qloss.save(os.path.join(model_path,'NN_qloss_model.h5'))
del model_mse, model_mae, model_mape, model_qloss

# %% [markdown]
# ### 4. Evaluate the trained model
#
# Now let's evaluate the trained NN on the test set, by comparing the NN predictions against the tas originally simulated under the ssp245 scenario.

# %%
# reload the saved model
model_mse = load_model(os.path.join(model_path,'NN_mse_model.h5'))
model_mae = load_model(os.path.join(model_path,'NN_mae_model.h5'))
model_mape = load_model(os.path.join(model_path,'NN_mape_model.h5'))
model_qloss = load_model(os.path.join(model_path,'NN_qloss_model.h5'),
                         custom_objects={'quantile_loss': quantile_loss}) # load model with custom loss

# %%
# generate the prediction
# ----------mse----------
y_test_mse_pre = model_mse.predict(X_test)
y_test_mse_pre = y_test_mse_pre.reshape(y_test_mse_pre.shape[0], 96, 144)

y_test_mse_pre = xr.Dataset(coords={'time': X_test_xr.time.values, 
                               'latitude': X_test_xr.latitude.values, 
                               'longitude': X_test_xr.longitude.values},
                       data_vars=dict(tas=(['time', 'latitude', 'longitude'], y_test_mse_pre)))
# ----------mae----------
y_test_mae_pre = model_mae.predict(X_test)
y_test_mae_pre = y_test_mae_pre.reshape(y_test_mae_pre.shape[0], 96, 144)

y_test_mae_pre = xr.Dataset(coords={'time': X_test_xr.time.values, 
                               'latitude': X_test_xr.latitude.values, 
                               'longitude': X_test_xr.longitude.values},
                       data_vars=dict(tas=(['time', 'latitude', 'longitude'], y_test_mae_pre)))
# ----------mape----------
y_test_mape_pre = model_mape.predict(X_test)
y_test_mape_pre = y_test_mape_pre.reshape(y_test_mape_pre.shape[0], 96, 144)

y_test_mape_pre = xr.Dataset(coords={'time': X_test_xr.time.values, 
                               'latitude': X_test_xr.latitude.values, 
                               'longitude': X_test_xr.longitude.values},
                       data_vars=dict(tas=(['time', 'latitude', 'longitude'], y_test_mape_pre)))
# ----------mse----------
y_test_qloss_pre = model_qloss.predict(X_test)
y_test_qloss_pre = y_test_qloss_pre.reshape(y_test_qloss_pre.shape[0], 96, 144)

y_test_qloss_pre = xr.Dataset(coords={'time': X_test_xr.time.values, 
                               'latitude': X_test_xr.latitude.values, 
                               'longitude': X_test_xr.longitude.values},
                       data_vars=dict(tas=(['time', 'latitude', 'longitude'], y_test_qloss_pre)))
# Out:
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step

# %% [markdown]
# First we check whether the ML model can capture the spatial distribution of global temperature

# %%
fig, axes = plt.subplots(figsize=(20,12),ncols=5,nrows=3)

yrs = [2030, 2050, 2100]
vmin, vmax    = -6, 6
cmap = 'RdBu_r'
y_test_mse_pre.tas.sel(time=yrs[0]).plot(ax=axes[0,0], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mae_pre.tas.sel(time=yrs[0]).plot(ax=axes[0,1], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mape_pre.tas.sel(time=yrs[0]).plot(ax=axes[0,2], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_qloss_pre.tas.sel(time=yrs[0]).plot(ax=axes[0,3], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_xr.tas.sel(time=yrs[0]).plot(ax=axes[0,4], vmin=vmin, vmax=vmax,cmap=cmap)

y_test_mse_pre.tas.sel(time=yrs[1]).plot(ax=axes[1,0], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mae_pre.tas.sel(time=yrs[1]).plot(ax=axes[1,1], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mape_pre.tas.sel(time=yrs[1]).plot(ax=axes[1,2], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_qloss_pre.tas.sel(time=yrs[1]).plot(ax=axes[1,3], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_xr.tas.sel(time=yrs[1]).plot(ax=axes[1,4], vmin=vmin, vmax=vmax,cmap=cmap)

y_test_mse_pre.tas.sel(time=yrs[2]).plot(ax=axes[2,0], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mae_pre.tas.sel(time=yrs[2]).plot(ax=axes[2,1], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mape_pre.tas.sel(time=yrs[2]).plot(ax=axes[2,2], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_qloss_pre.tas.sel(time=yrs[2]).plot(ax=axes[2,3], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_xr.tas.sel(time=yrs[2]).plot(ax=axes[2,4], vmin=vmin, vmax=vmax,cmap=cmap)


for i, ax in enumerate(axes.flat):
    # left column: model prediction
    if i % 5 == 0:
        ax.set_title(f'tas prediction (mse, {yrs[i//5]})',fontweight='bold')
    elif i % 5 == 1:
        ax.set_title(f'tas prediction (mae, {yrs[i//5]})',fontweight='bold')
    elif i % 5 == 2:
        ax.set_title(f'tas prediction (mape, {yrs[i//5]})',fontweight='bold')
    elif i % 5 == 3:
        ax.set_title(f'tas prediction (qloss, {yrs[i//5]})',fontweight='bold')
    # right column: truth tas from ssp245 simulations
    else:
        ax.set_title(f'tas truth (year = {yrs[i//5]})',fontweight='bold')
plt.tight_layout()

# %% [markdown]
# Then we also check whether the ML model can reproduce the time series of a given location.<br/> Here we take NYC as an example (40.7128° N, 74.0060° W)

# %%
lat = 40.7128
lon = -74.0060%360

fig,ax = plt.subplots(figsize=(9,4))
y_test_xr.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,color='tab:blue',label='truth')
y_test_mse_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,color='tab:orange',label='prediction (mse)')
y_test_mae_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,color='tab:brown',label='prediction (mae)')
y_test_mape_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,color='tab:gray',label='prediction (mape)')
y_test_qloss_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,color='tab:pink',label='prediction (qloss)')

ax.legend()
ax.set_ylabel('temperature (°C)')

plt.tight_layout()

# %% [markdown]
# Finally we check whether the ML model can capture the time series of global average temperature

# %%
def global_mean_std_plot(X,label,color,ax,var='tas'):
    weights  = np.cos(np.deg2rad(X.latitude))
    tas_mean = X[var].weighted(weights).mean(['latitude', 'longitude']).data
    tas_std  = X[var].weighted(weights).std(['latitude', 'longitude']).data
    
    x = X.time.data

    ax.plot(x, tas_mean, label=label,color=color,linewidth=2)
    ax.fill_between(x,tas_mean+tas_std,tas_mean-tas_std,facecolor=color,alpha=0.2)

# %%
fig,ax = plt.subplots(figsize=(9,4))

global_mean_std_plot(y_test_xr,label='truth',ax=ax,color='tab:blue')
global_mean_std_plot(y_test_mse_pre,label='prediction (mse)',ax=ax,color='tab:orange')
global_mean_std_plot(y_test_mae_pre,label='prediction (mae)',ax=ax,color='tab:brown')
global_mean_std_plot(y_test_mape_pre,label='prediction (mape)',ax=ax,color='tab:gray')
global_mean_std_plot(y_test_qloss_pre,label='prediction (qloss)',ax=ax,color='tab:pink')

ax.set_xlabel('time')
ax.set_ylabel('global mean temperature (°C)')
ax.legend()
plt.tight_layout()
